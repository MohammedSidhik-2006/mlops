# %%
import pandas as pd
import numpy as np

from sklearn import linear_model

# %%
import os
print(os.listdir())
# Out:
# Running cells with 'Python 3.13.5' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Python313/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
df = pd.read_csv(r"D:\MODEL SAVING\homeprices.csv")
df.head()
# Out:
# Running cells with 'Python 3.13.5' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Python313/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
model = linear_model.LinearRegression()
model.fit(df[['area']],df.price)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
model.coef_
# Out:
# array([135.78767123])

# %%
model.intercept_
# Out:
# 180616.43835616432

# %%
model.predict([[5000]])
# Out:
# array([859554.79452055])

# %% [markdown]
# <h3 style='color:purple'>Save Model To a File Using Python Pickle</h3>

# %%
import pickle

# %%
with open('model_pickle','wb') as file:
    pickle.dump(model,file)

# %% [markdown]
# <h4 style='color:purple'>Load Saved Model</h4>

# %%
with open('model_pickle','rb') as file:
    mp = pickle.load(file)

# %%
mp.coef_
# Out:
# array([135.78767123])

# %%
mp.intercept_
# Out:
# 180616.43835616432

# %%
mp.predict([[5000]])
# Out:
# array([859554.79452055])

# %% [markdown]
# <h3 style='color:purple'>Save Trained Model Using joblib</h3>
#
# https://scikit-learn.org/0.19/modules/model_persistence.html

# %%
from sklearn.externals import joblib

# %%
joblib.dump(model, 'model_joblib')
# Out:
# ['model_joblib']

# %% [markdown]
# <h4 style='color:purple'>Load Saved Model</h4>

# %%
mj = joblib.load('model_joblib')

# %%
mj.coef_
# Out:
# array([135.78767123])

# %%
mj.intercept_
# Out:
# 180616.43835616432

# %%
mj.predict([[5000]])
# Out:
# array([859554.79452055])
